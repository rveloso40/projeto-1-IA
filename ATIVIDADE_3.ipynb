# %%
print ("ola mundao")
# Out:
# ola mundao

# %% [markdown]
# #CETAM-CENTRO DE TECNOLOGIA DO AMAZONASA IBC
# ##MANAUS 23 DE MARÇO DE 2026
# ###CURSO TECNICO EM NIVEL MEDIO EM IA
#
# ATIVIDADE 3
#
# ALUNO: MAURICIO VELOSO

# %%
2+3
# Out:
# 5

# %%
50-5*7
# Out:
# 15

# %%
(50-5*6)/2
# Out:
# 10.0

# %%
print(int (8/5)) #divisao com operadores inteiros, retorna resultados inteiros (vc.2.7)

print(8./5) #divisao com pelo menos um operador real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2 # 5 elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin (numero)
print(resultado) # saida
# Out:
# 0b111011
