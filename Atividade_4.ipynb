# %% [markdown]
# ***CETAM - CENTRO DE TECNOLOGIA DO AMAZONAS***
#
# *ALUNO: MAURÍCIO VELOSO*
#
# MANAUS 24 DE MARÇO DE 2026

# %%
nu1, nu2 = 0,0
print ('ola mundo !!')

print (5+5-2)
print (nu1)

print (5**2)
print (nu2)
# Out:
# ola mundo !!
# 8
# 0
# 25
# 0

# %%
# Script 1
# função criada pelo usuário
def dobro (x):
  print (x * 2)

  dobro (125)

# %%
print ("Curso Tecnico em inteligencia Artificial em Nivel Médio - Turma 2026")
# Out:
# Curso Tecnico em inteligencia Artificial em Nivel Médio - Turma 2026
